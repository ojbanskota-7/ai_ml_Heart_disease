# %% [markdown]
# ### Comparison of Task 1 and Task 2 Models
#
# 1. **Performance Metrics**
#    - Task 1 (Single Feature: Cholesterol):
#      - Accuracy: *0.61111*
#      - Recall: *0.238095*
#      - F1-score: *0.3225*
#      - Precision : *0.5*
#    - Task 2 (Multiple Features: All variables):
#      - Accuracy: *0.9074*
#      - Recall: *0.8571*
#      - F1-score: *0.7880*
#      - Precision : *0.9*
#
# 2. **Which model performs better and why**
#    - Task 2 generally performs better because it **uses all relevant features**, capturing more relationships that influence heart disease risk.
#    - Task 1 is simpler but limited: it only considers **Cholesterol**, so many patterns are missed.
#
# 3. **Effect of adding more features**
#    - **Accuracy** usually increases because the model has more information to make correct predictions.
#    - **Recall** may improve for the positive class (presence of disease) because the model can detect subtle patterns.
#    - However, adding irrelevant or noisy features could sometimes hurt generalization (overfitting).
#
# 4. **Trade-offs**
#    - **Single Feature (Task 1)**:
#      -  Easy to interpret and visualize (coefficients show clear effect).
#      -  Lower performance, misses interactions between features.
#    - **Multiple Features (Task 2)**:
#      -  Higher accuracy and better detection of heart disease.
#      -  Harder to interpret; coefficients are harder to explain when there are many features.

# %%
# This cell is added to ensure GitHub renders the notebook correctly
print("Notebook loaded successfully")
# Out:
# Notebook loaded successfully
